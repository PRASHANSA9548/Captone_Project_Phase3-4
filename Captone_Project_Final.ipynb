# %% [markdown]
# # Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df1=pd.read_csv('imbd.csv')
df1
# Out:
#       Sl No                                        Movie Name1  Time Duration  \
# 0         1                Spider-Man: Across the Spider-Verse            140
# 1         2                                    The Dark Knight            152
# 2         3      The Lord of the Rings: The Return of the King            201
# 3         4                                          Inception            148
# 4         5  The Lord of the Rings: The Fellowship of the Ring            178
# ...     ...                                                ...            ...
# 1745   1746                               Dragonball Evolution             85
# 1746   1747                                  Battlefield Earth            118
# 1747   1748                                        Heropanti 2            145
# 1748   1749                                             Laxmii            141
# 1749   1750                                  Alone in the Dark             99
#
# ...

# %%
df1.drop(['Director1','Director2','Director3','Director4','Director5','Director6'],axis=1,inplace=True)
df1
# Out:
#       Sl No                                        Movie Name1  Time Duration  \
# 0         1                Spider-Man: Across the Spider-Verse            140
# 1         2                                    The Dark Knight            152
# 2         3      The Lord of the Rings: The Return of the King            201
# 3         4                                          Inception            148
# 4         5  The Lord of the Rings: The Fellowship of the Ring            178
# ...     ...                                                ...            ...
# 1745   1746                               Dragonball Evolution             85
# 1746   1747                                  Battlefield Earth            118
# 1747   1748                                        Heropanti 2            145
# 1748   1749                                             Laxmii            141
# 1749   1750                                  Alone in the Dark             99
#
# ...

# %%
df1.columns
# Out:
# Index(['Sl No', 'Movie Name1', 'Time Duration', 'Year', 'Ratings', 'Metascore',
#        'Director'],
#       dtype='object')

# %%
df2=pd.read_csv('imbd2.csv')
df2
# Out:
#                                              Movie Name    Votes  \
# 0                   Spider-Man: Across the Spider-Verse   141390
# 1                                       The Dark Knight  2727883
# 2         The Lord of the Rings: The Return of the King  1892289
# 3                                             Inception  2420963
# 4     The Lord of the Rings: The Fellowship of the Ring  1920802
# ...                                                 ...      ...
# 1745                               Dragonball Evolution    77191
# 1746                                  Battlefield Earth    81717
# 1747                                        Heropanti 2    27015
# 1748                                             Laxmii    58067
# 1749                                  Alone in the Dark    46421
#
#                                Genre  Gross Collection in USD(Million)  \
# 0     Animation/ Action/ Adventure                                0.00
# ...

# %%
df2.drop(['Star1','Star2','Star3','Star4','Genre1','Genre2','Genre3'],axis=1,inplace=True)
df2
# Out:
#                                              Movie Name    Votes  \
# 0                   Spider-Man: Across the Spider-Verse   141390
# 1                                       The Dark Knight  2727883
# 2         The Lord of the Rings: The Return of the King  1892289
# 3                                             Inception  2420963
# 4     The Lord of the Rings: The Fellowship of the Ring  1920802
# ...                                                 ...      ...
# 1745                               Dragonball Evolution    77191
# 1746                                  Battlefield Earth    81717
# 1747                                        Heropanti 2    27015
# 1748                                             Laxmii    58067
# 1749                                  Alone in the Dark    46421
#
#                                Genre  Gross Collection in USD(Million)  \
# 0     Animation/ Action/ Adventure                                0.00
# ...

# %%
df3=pd.concat([df1,df2],axis=1)

# %%
df3
# Out:
#       Sl No                                        Movie Name1  Time Duration  \
# 0         1                Spider-Man: Across the Spider-Verse            140
# 1         2                                    The Dark Knight            152
# 2         3      The Lord of the Rings: The Return of the King            201
# 3         4                                          Inception            148
# 4         5  The Lord of the Rings: The Fellowship of the Ring            178
# ...     ...                                                ...            ...
# 1745   1746                               Dragonball Evolution             85
# 1746   1747                                  Battlefield Earth            118
# 1747   1748                                        Heropanti 2            145
# 1748   1749                                             Laxmii            141
# 1749   1750                                  Alone in the Dark             99
#
# ...

# %%
df3.shape
# Out:
# (1750, 14)

# %%
df3.columns
# Out:
# Index(['Sl No', 'Movie Name1', 'Time Duration', 'Year', 'Ratings', 'Metascore',
#        'Director', 'Movie Name', 'Votes', 'Genre',
#        'Gross Collection in USD(Million)', 'Certificate', 'Stars',
#        'Popularity'],
#       dtype='object')

# %%
df3.drop(['Movie Name'],axis=1,inplace=True)
df3
# Out:
#       Sl No                                        Movie Name1  Time Duration  \
# 0         1                Spider-Man: Across the Spider-Verse            140
# 1         2                                    The Dark Knight            152
# 2         3      The Lord of the Rings: The Return of the King            201
# 3         4                                          Inception            148
# 4         5  The Lord of the Rings: The Fellowship of the Ring            178
# ...     ...                                                ...            ...
# 1745   1746                               Dragonball Evolution             85
# 1746   1747                                  Battlefield Earth            118
# 1747   1748                                        Heropanti 2            145
# 1748   1749                                             Laxmii            141
# 1749   1750                                  Alone in the Dark             99
#
# ...

# %%
df3.head()
# Out:
#    Sl No                                        Movie Name1  Time Duration  \
# 0      1                Spider-Man: Across the Spider-Verse            140
# 1      2                                    The Dark Knight            152
# 2      3      The Lord of the Rings: The Return of the King            201
# 3      4                                          Inception            148
# 4      5  The Lord of the Rings: The Fellowship of the Ring            178
#
#    Year  Ratings  Metascore  \
# 0  2023      9.0         86
# 1  2008      9.0         84
# 2  2003      9.0         94
# 3  2010      8.8         74
# 4  2001      8.8         92
#
#                                             Director    Votes  \
# 0  sJoaquim Dos Santos/ Kemp Powers/ Justin K. Th...   141390
# 1                                  Christopher Nolan  2727883
# 2                                      Peter Jackson  1892289
# 3                                  Christopher Nolan  2420963
# ...

# %%
df3.shape
# Out:
# (1750, 13)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1750 entries, 0 to 1749
# Data columns (total 13 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Sl No                             1750 non-null   int64
#  1   Movie Name1                       1750 non-null   object
#  2   Time Duration                     1750 non-null   int64
#  3   Year                              1750 non-null   int64
#  4   Ratings                           1750 non-null   float64
#  5   Metascore                         1750 non-null   int64
#  6   Director                          1750 non-null   object
#  7   Votes                             1750 non-null   int64
#  8   Genre                             1750 non-null   object
#  9   Gross Collection in USD(Million)  1750 non-null   float64
#  10  Certificate                       1750 non-null   object
# ...

# %%
df3.dtypes
# Out:
# Sl No                                 int64
# Movie Name1                          object
# Time Duration                         int64
# Year                                  int64
# Ratings                             float64
# Metascore                             int64
# Director                             object
# Votes                                 int64
# Genre                                object
# Gross Collection in USD(Million)    float64
# Certificate                          object
# Stars                                object
# Popularity                          float64
# dtype: object

# %%
df3.isnull().sum()
# Out:
# Sl No                               0
# Movie Name1                         0
# Time Duration                       0
# Year                                0
# Ratings                             0
# Metascore                           0
# Director                            0
# Votes                               0
# Genre                               0
# Gross Collection in USD(Million)    0
# Certificate                         0
# Stars                               0
# Popularity                          0
# dtype: int64

# %%
df3.nunique()
# Out:
# Sl No                               1750
# Movie Name1                         1719
# Time Duration                        120
# Year                                  74
# Ratings                               62
# Metascore                             87
# Director                             947
# Votes                               1742
# Genre                                 80
# Gross Collection in USD(Million)    1357
# Certificate                           23
# Stars                               1729
# Popularity                            62
# dtype: int64

# %%
df3_class=df3.copy()

# %% [markdown]
# # EDA Analysis

# %%
sns.heatmap(df3.isnull())
plt.show()

# %%
percentage_missing=df3.isnull().sum()*100/len(df3)
print(percentage_missing)
# Out:
# Sl No                               0.0
# Movie Name1                         0.0
# Time Duration                       0.0
# Year                                0.0
# Ratings                             0.0
# Metascore                           0.0
# Director                            0.0
# Votes                               0.0
# Genre                               0.0
# Gross Collection in USD(Million)    0.0
# Certificate                         0.0
# Stars                               0.0
# Popularity                          0.0
# dtype: float64

# %%
plt.figure(figsize=(9,15))
sns.pairplot(df3)

# %%
sns.countplot(df3['Year'],color='b')
plt.show()

# %% [markdown]
# # Data (Preparation)

# %%
df3.corr()
# Out:
#                                      Sl No  Time Duration      Year   Ratings  \
# Sl No                             1.000000      -0.376922  0.138419 -0.956529
# Time Duration                    -0.376922       1.000000  0.133425  0.364062
# Year                              0.138419       0.133425  1.000000 -0.129407
# Ratings                          -0.956529       0.364062 -0.129407  1.000000
# Metascore                        -0.424513       0.012817 -0.141707  0.415444
# Votes                            -0.429943       0.278330  0.056325  0.434512
# Gross Collection in USD(Million) -0.243039       0.242303  0.064568  0.234795
# Popularity                       -0.956529       0.364062 -0.129407  1.000000
#
#                                   Metascore     Votes  \
# Sl No                             -0.424513 -0.429943
# Time Duration                      0.012817  0.278330
# Year                              -0.141707  0.056325
# ...

# %%
plt.figure(figsize=(18,8))
sns.heatmap(df3.corr(),annot=True,linewidth=4,linecolor='blue')
plt.show()

# %%
df3.dropna(axis=0)
# Out:
#       Sl No                                        Movie Name1  Time Duration  \
# 0         1                Spider-Man: Across the Spider-Verse            140
# 1         2                                    The Dark Knight            152
# 2         3      The Lord of the Rings: The Return of the King            201
# 3         4                                          Inception            148
# 4         5  The Lord of the Rings: The Fellowship of the Ring            178
# ...     ...                                                ...            ...
# 1745   1746                               Dragonball Evolution             85
# 1746   1747                                  Battlefield Earth            118
# 1747   1748                                        Heropanti 2            145
# 1748   1749                                             Laxmii            141
# 1749   1750                                  Alone in the Dark             99
#
# ...

# %%
duplicate_data=df3.duplicated().any()
print(duplicate_data)
# Out:
# False

# %%
df3.describe()
# Out:
#              Sl No  Time Duration         Year      Ratings    Metascore  \
# count  1750.000000    1750.000000  1750.000000  1750.000000  1750.000000
# mean    875.500000     115.415429  2006.097143     6.499200    47.928000
# std     505.325802      21.753005    13.259332     0.953396    22.313978
# min       1.000000      45.000000  1924.000000     2.400000     0.000000
# 25%     438.250000     100.000000  2000.000000     5.900000    37.000000
# 50%     875.500000     112.000000  2009.000000     6.500000    50.500000
# 75%    1312.750000     127.000000  2016.000000     7.100000    64.000000
# max    1750.000000     321.000000  2023.000000     9.000000    98.000000
#
#               Votes  Gross Collection in USD(Million)   Popularity
# count  1.750000e+03                       1750.000000  1750.000000
# mean   1.813953e+05                         64.856463     6.499200
# std    2.371229e+05                         98.555917     0.953396
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(round(df3.describe()[1:].transpose(),2),annot=True,fmt='.2f',linecolor='b',linewidth=4)
plt.show()

# %%
df3.columns
# Out:
# Index(['Sl No', 'Movie Name1', 'Time Duration', 'Year', 'Ratings', 'Metascore',
#        'Director', 'Votes', 'Genre', 'Gross Collection in USD(Million)',
#        'Certificate', 'Stars', 'Popularity'],
#       dtype='object')

# %%
df3[df3['Time Duration']>=180]['Movie Name1']
# Out:
# 2           The Lord of the Rings: The Return of the King
# 11                                   Shichinin no samurai
# 18                                      Avengers: Endgame
# 48                                     Gangs of Wasseypur
# 74                                                 Sholay
# 83                           Zack Snyder's Justice League
# 101                                           Arjun Reddy
# 135                                RRR (Rise Roar Revolt)
# 199                              Avatar: The Way of Water
# 259                          It's a Mad Mad Mad Mad World
# 264                                            Grindhouse
# 278                                          Jodhaa Akbar
# 368                                               Ghajini
# 383     Batman v Superman: Dawn of Justice (Ultimate E...
# 384                                             King Kong
# 713                                            Wyatt Earp
# ...

# %%
df3.groupby('Year')['Votes'].mean().sort_values(ascending=False)
# Out:
# Year
# 1977    521273.333333
# 1954    353687.000000
# 1980    345428.200000
# 1959    335328.000000
# 2003    253828.595745
#             ...
# 1975     37866.333333
# 1953     37248.000000
# 1949     34348.000000
# 1966     32052.500000
# 1932     29164.000000
# Name: Votes, Length: 74, dtype: float64

# %%
plt.figure(figsize=(35,18))
sns.barplot(x='Year',y='Votes',data=df3)
plt.title("Average votes by year")
plt.show()

# %%
df3.groupby('Year')['Gross Collection in USD(Million)'].mean().sort_values(ascending=False)
# Out:
# Year
# 1977    165.426667
# 1980     94.510000
# 1983     93.744286
# 2017     91.730328
# 2018     88.668551
#            ...
# 1958      0.000000
# 1949      0.000000
# 1948      0.000000
# 1932      0.000000
# 2023      0.000000
# Name: Gross Collection in USD(Million), Length: 74, dtype: float64

# %%
plt.figure(figsize=(35,18))
sns.barplot(x='Year',y='Gross Collection in USD(Million)',data=df3)
plt.title("Average Gross Collection in USD(Million) by year")
plt.show()

# %%
df3.groupby('Year')['Ratings'].mean().sort_values(ascending=False)
# Out:
# Year
# 1954    8.600000
# 1959    8.300000
# 1924    8.200000
# 1958    8.100000
# 1949    8.100000
#           ...
# 2000    6.268571
# 2020    6.268293
# 1996    6.204000
# 2005    6.190698
# 1997    6.176316
# Name: Ratings, Length: 74, dtype: float64

# %%
plt.figure(figsize=(35,18))
sns.barplot(x='Year',y='Ratings',data=df3)
plt.title("Average Ratings by year")
plt.show()

# %%
df3.groupby('Director')['Ratings'].mean().sort_values()
# Out:
# Director
# Ahmed Khan                                              2.500000
# Roger Christian                                         2.500000
# sRaghava Lawrence/ Balakrishnan Thevar                  2.500000
# Puri Jagannadh                                          2.700000
# Uwe Boll                                                3.066667
#                                                           ...
# Peter Jackson                                           8.450000
# Hanu Raghavapudi                                        8.600000
# Masaki Kobayashi                                        8.600000
# Sudha Kongara                                           8.700000
# sJoaquim Dos Santos/ Kemp Powers/ Justin K. Thompson    9.000000
# Name: Ratings, Length: 947, dtype: float64

# %%
df3['Year'].value_counts()
# Out:
# 2016    78
# 2014    77
# 2011    69
# 2018    69
# 2019    67
#         ..
# 1948     1
# 1932     1
# 1949     1
# 1938     1
# 1965     1
# Name: Year, Length: 74, dtype: int64

# %%
plt.figure(figsize=(35,18))
sns.countplot(x='Year',data=df3)
plt.show()

# %%
df3['Gross Collection in USD(Million)'].max()
# Out:
# 936.66

# %%
df3[df3['Gross Collection in USD(Million)'].max()==df3['Gross Collection in USD(Million)']]['Movie Name1']
# Out:
# 140    Star Wars: Episode VII - The Force Awakens
# Name: Movie Name1, dtype: object

# %%
df3['Votes'].max()
# Out:
# 2727883

# %%
df3[df3['Votes'].max()==df3['Votes']]['Movie Name1']
# Out:
# 1    The Dark Knight
# Name: Movie Name1, dtype: object

# %%
df3.drop(["Popularity","Certificate"],axis=1,inplace=True)
df3.sample()
# Out:
#       Sl No            Movie Name1  Time Duration  Year  Ratings  Metascore  \
# 1224   1225  The Jewel of the Nile            106  1985      6.1         53
#
#           Director  Votes                        Genre  \
# 1224  Lewis Teague  60001  Action/ Adventure/ Comedy
#
#       Gross Collection in USD(Million)  \
# 1224                             75.97
#
#                                                   Stars
# 1224  Michael Douglas/ Kathleen Turner/ Danny DeVito...

# %% [markdown]
# Using Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
Le=LabelEncoder
code=["Movie Name1","Director","Genre","Stars"]
for p in code:
    Le=LabelEncoder()
    Le.fit(df3[p])
    df3[p]=Le.fit_transform(df3[p])
df3
# Out:
#       Sl No  Movie Name1  Time Duration  Year  Ratings  Metascore  Director  \
# 0         1         1162            140  2023      9.0         86       908
# 1         2         1313            152  2008      9.0         84       135
# 2         3         1418            201  2003      9.0         94       608
# 3         4          607            148  2010      8.8         74       135
# 4         5         1417            178  2001      8.8         92       608
# ...     ...          ...            ...   ...      ...        ...       ...
# 1745   1746          377             85  2009      2.6         45       331
# 1746   1747          159            118  2000      2.5          9       683
# 1747   1748          559            145  2022      2.5          0        10
# 1748   1749          744            141  2020      2.5          0       934
# 1749   1750           72             99  2005      2.4          9       824
#
# ...

# %% [markdown]
# Using Z Score

# %%
from scipy.stats import zscore
z=np.abs(zscore(df3))
z
# Out:
#          Sl No  Movie Name1  Time Duration      Year   Ratings  Metascore  \
# 0     1.731061     0.607952       1.130492  1.275154  2.623793   1.706683
# 1     1.729082     0.912206       1.682298  0.143552  2.623793   1.617027
# 2     1.727102     1.123773       3.935504  0.233649  2.623793   2.065305
# 3     1.725123     0.510331       1.498362  0.294432  2.413957   1.168750
# 4     1.723143     1.121758       2.877876  0.384529  2.413957   1.975649
# ...        ...          ...            ...       ...       ...        ...
# 1745  1.723143     0.973763       1.398617  0.218992  4.090969   0.131256
# 1746  1.725123     1.413017       0.118848  0.459969  4.195887   1.745055
# 1747  1.727102     0.607047       1.360411  1.199714  4.195887   2.148505
# 1748  1.729082     0.234286       1.176476  1.048833  4.195887   2.148505
# 1749  1.731061     1.588315       0.754844  0.082769  4.300805   1.745055
#
#       Director      Votes     Genre  Gross Collection in USD(Million)  \
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([   1,    1,    2,    2,    2,    3,    4,    5,    6,    7,    9,
#          10,   11,   11,   12,   14,   15,   17,   18,   18,   18,   21,
#          21,   22,   22,   25,   27,   29,   37,   37,   38,   40,   42,
#          43,   44,   48,   49,   51,   51,   58,   60,   70,   71,   72,
#          74,   81,   83,   84,   84,   86,   86,   98,  101,  107,  107,
#         108,  117,  123,  129,  135,  139,  140,  140,  141,  178,  180,
#         183,  193,  194,  199,  199,  200,  213,  216,  251,  259,  259,
#         264,  269,  278,  285,  293,  296,  299,  326,  334,  337,  356,
#         364,  368,  375,  375,  383,  384,  399,  409,  444,  542,  562,
#         563,  565,  579,  587,  625,  672,  713,  843,  844,  900, 1077,
#        1172, 1311, 1470, 1733, 1734, 1735, 1736, 1737, 1738, 1739, 1740,
#        1741, 1742, 1743, 1744, 1745, 1746, 1747, 1748, 1749], dtype=int64), array([7, 9, 2, 7, 9, 7, 7, 7, 7, 7, 7, 7, 2, 3, 3, 7, 7, 7, 2, 7, 9, 7,
# ...

# %%
df3_new=df3[(z<3).all(axis=1)]
print("original shape=",df3.shape)
print("new shape=",df3_new.shape)
# Out:
# original shape= (1750, 11)
# new shape= (1637, 11)

# %%
df3.skew()
# Out:
# Sl No                               0.000000
# Movie Name1                        -0.002446
# Time Duration                       1.486153
# Year                               -1.490447
# Ratings                            -0.488548
# Metascore                          -0.634685
# Director                           -0.063180
# Votes                               3.809343
# Genre                               0.605271
# Gross Collection in USD(Million)    3.411043
# Stars                              -0.004698
# dtype: float64

# %%
df3.sample()
# Out:
#      Sl No  Movie Name1  Time Duration  Year  Ratings  Metascore  Director  \
# 144    145         1122            143  2012      7.8         81       707
#
#       Votes  Genre  Gross Collection in USD(Million)  Stars
# 144  710944     13                            304.36    352

# %%
x=df3.drop(["Votes"],axis=1)  
y=df3["Votes"]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x= sc.fit_transform(x)

# %%
x=pd.DataFrame(x)
x
# Out:
#              0         1         2         3         4         5         6  \
# 0    -1.731061  0.607952  1.130492  1.275154  2.623793  1.706683  1.664829
# 1    -1.729082  0.912206  1.682298  0.143552  2.623793  1.617027 -1.310759
# 2    -1.727102  1.123773  3.935504 -0.233649  2.623793  2.065305  0.510008
# 3    -1.725123 -0.510331  1.498362  0.294432  2.413957  1.168750 -1.310759
# 4    -1.723143  1.121758  2.877876 -0.384529  2.413957  1.975649  0.510008
# ...        ...       ...       ...       ...       ...       ...       ...
# 1745  1.723143 -0.973763 -1.398617  0.218992 -4.090969 -0.131256 -0.556276
# 1746  1.725123 -1.413017  0.118848 -0.459969 -4.195887 -1.745055  0.798713
# 1747  1.727102 -0.607047  1.360411  1.199714 -4.195887 -2.148505 -1.791934
# 1748  1.729082 -0.234286  1.176476  1.048833 -4.195887 -2.148505  1.764913
# 1749  1.731061 -1.588315 -0.754844 -0.082769 -4.300805 -1.745055  1.341479
#
#              7         8         9
# ...

# %% [markdown]
# Power transformation to reduce skewness

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %% [markdown]
# # Selecting the best random state

# %%
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
best_random_state=0
accu=0
for i in range(50,700):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=i)
    mod=LinearRegression()
    mod.fit(x_train,y_train)
    y_pred=mod.predict(x_test)
    tempaccu=r2_score(y_test,y_pred)
    cscore=cross_val_score(mod,x,y,cv=5).mean()
    
    
    if tempaccu>accu:
        accu=tempaccu
        best_random_state=i
        
        
print('Best accuracy is ',(accu*100),'found on random state',(best_random_state),'with cross validation=',(cscore*100))
# Out:
# Best accuracy is  63.183705968660654 found on random state 494 with cross validation= -410.6387665341305

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=494)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score
from sklearn.linear_model import Lasso,Ridge

models=[LinearRegression(),DecisionTreeRegressor(),Lasso(),Ridge()]

for i in models:
    i.fit(x_train,y_train)
    pred_y=i.predict(x_test)
    print("for",i,"algorithm")
    print(f"r2 score is",(r2_score(y_test,pred_y)*100))
    cross_score=cross_val_score(i,x,y,cv=3).mean()*100
    print("cross validation score is",cross_score)
    print('\n')
# Out:
# for LinearRegression() algorithm
# r2 score is 63.183705968660654
# cross validation score is -292.82266713032396
#
#
# for DecisionTreeRegressor() algorithm
# r2 score is 57.79230052370288
# cross validation score is 1.3753415241114397
#
#
# for Lasso() algorithm
# r2 score is 63.183793203735014
# cross validation score is -292.77884282368893
#
#
# for Ridge() algorithm
# r2 score is 63.18613199952796
# cross validation score is -279.04838345684567

# %% [markdown]
# Linear Regression

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
import numpy as np
Lr=LinearRegression()
Lr.fit(x_train,y_train)
y_pred=Lr.predict(x_test)
print("r2 score=",r2_score(y_test,y_pred)*100)
cv=cross_val_score(Lr,x,y,cv=3).mean()*100
print("cross validation score is",cv)
print("mean absolute error=",mean_absolute_error(y_test,y_pred))
print("mean squared error=",mean_squared_error(y_test,y_pred))
print("root mean squared error=",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2 score= 63.183705968660654
# cross validation score is -292.82266713032396
# mean absolute error= 93000.91206118437
# mean squared error= 17753313104.025814
# root mean squared error= 133241.5592224356

# %% [markdown]
# Saving the trained model

# %%
import pickle
filename='Captone_Project_Final.pkl'
pickle.dump(Lr,open(filename,'wb'))

# %%
import numpy as np
a=np.array(y_test)
a
# Out:
# array([  38170,  171085,   38553,   62756,   46285,   33577,  154390,
#         103001,   37130,   46432,  315057,   61677,   85082,   83728,
#         478492,  182697,   40402,  513287,  426771,  126171,   48985,
#         871453,  116367,   39778,   34071,  307384,   68417,   98178,
#         100178,  208012,   28992,   29559,   61211,   73345,  112548,
#          36381,  596395,   33307,  121974,   89608,  112185,   33029,
#          82116,   37078,   52041,   59101,  226082,   29607,  129628,
#          26798,   42391,   56756,  179991,  223081,  683494,  102214,
#         173465,  113726,   48089,   48564,  649291,  372800,  283388,
#         175108,  163763,   98912,  306107,   35255,  247418,   45149,
#         512573,   89998,  458323,  469200,   25729,  224058,   42904,
#          94218,  238774,   49770,  301193,   47557,  655133,   51202,
#          73336,   47337,   53529,  118704,   89567,   48479,  476122,
# ...

# %%
predicted=np.array(Lr.predict(x_test))
predicted
# Out:
# array([-7.32388761e+04,  4.04935886e+05, -1.12012441e+05,  1.51417795e+05,
#        -7.62666173e+04,  1.09318726e+05,  5.43304000e+04,  5.76978479e+04,
#         1.70323963e+05,  1.43174650e+05,  3.85993158e+05,  1.34371472e+05,
#         1.55856817e+05,  1.71683653e+05,  5.33022612e+05,  1.64370711e+05,
#         2.00462636e+05,  3.14263965e+05,  5.05535733e+05,  1.94030013e+05,
#         3.39231486e+04,  4.90613247e+05,  1.25557480e+05,  6.63351150e+04,
#        -6.76156451e+04,  3.22985192e+05,  3.73141208e+04,  2.98980065e+05,
#         1.48790434e+04,  2.70960840e+05,  1.95708501e+04,  6.04442268e+04,
#         2.13688658e+05,  1.12675240e+05,  6.02948026e+04,  2.11161577e+05,
#         2.10676117e+05, -2.54963327e+02,  7.81040749e+04,  7.68313347e+04,
#         1.67357602e+05,  8.35334879e+04,  1.29569338e+05,  2.97992522e+04,
#        -2.01850747e+05,  1.94388411e+04,  2.64372098e+05,  1.86715300e+05,
# ...

# %% [markdown]
# # Votes Predictions

# %%
df3_mod=pd.DataFrame({'original':a,'predicted':predicted})
df3_mod
# Out:
#      original      predicted
# 0       38170  -73238.876076
# 1      171085  404935.886088
# 2       38553 -112012.440724
# 3       62756  151417.795078
# 4       46285  -76266.617302
# ..        ...            ...
# 433     97046  211306.662936
# 434     86133  213368.630327
# 435    269460  295622.333330
# 436     69282   82832.589023
# 437    493366  480087.072865
#
# [438 rows x 2 columns]

# %% [markdown]
# # Performing Classification for same dataset

# %%
df3_class 
df3_class.shape
# Out:
# (1750, 13)

# %%
df3_class.sample()
# Out:
#      Sl No                      Movie Name1  Time Duration  Year  Ratings  \
# 251    252  The Hunger Games: Catching Fire            146  2013      7.5
#
#      Metascore          Director   Votes                        Genre  \
# 251         76  Francis Lawrence  685249  Action/ Adventure/ Sci-Fi
#
#      Gross Collection in USD(Million) Certificate  \
# 251                            424.67          UA
#
#                                                  Stars  Popularity
# 251  Jennifer Lawrence/ Josh Hutcherson/ Liam Hemsw...         7.5

# %%
df3_class.drop(["Popularity","Certificate"],axis=1,inplace=True)
df3.sample()
# Out:
#       Sl No  Movie Name1  Time Duration  Year  Ratings  Metascore  Director  \
# 1728   1729          605            127  2007      3.8         15       824
#
#       Votes  Genre  Gross Collection in USD(Million)  Stars
# 1728  50213      7                              4.54    724

# %%
v=["Movie Name1","Director","Genre","Stars"]
for p in v:
    Le=LabelEncoder()
    Le.fit(df3_class[p])
    df3_class[p]=Le.fit_transform(df3_class[p])

# %%
df3_class.sample()
# Out:
#       Sl No  Movie Name1  Time Duration  Year  Ratings  Metascore  Director  \
# 1250   1251           11            148  2018      6.1          0       702
#
#       Votes  Genre  Gross Collection in USD(Million)  Stars
# 1250  25729     69                              5.57   1267

# %%
x1=df3_class.drop(["Votes"],axis=1)
y1=df3_class["Votes"]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x1= sc.fit_transform(x1)

# %%
from sklearn.preprocessing import power_transform
x1=power_transform(x1,method='yeo-johnson')

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

best_random_state=0
accu=0

for i in range(0,400):
    x_train,x_test,y_train,y_test=train_test_split(x1,y1,test_size=30,random_state=i)
    dc=DecisionTreeClassifier()
    dc.fit(x_train,y_train)
    y_pred=dc.predict(x_test)
    tempaccu=accuracy_score(y_test,y_pred)
   
    
    if tempaccu>accu:
        accu=tempaccu
        best_rstate=i
       
        
        
print('Best accuracy is ',(accu*100),'found on random state',(best_random_state))

# %%
x_train,x_test,y_train,y_test=train_test_split(x1,y1,test_size=30,random_state=23)

# %%
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

models=[SVC(),DecisionTreeClassifier(),KNeighborsClassifier()]

for i in models:
    i.fit(x_train,y_train)
    pred_y=i.predict(x_test)
    print("for",i,"algorithm")
    print(f"accuracy score is {accuracy_score(y_test,pred_y)*100}")
    crossval=cross_val_score(i,x1,y1,cv=5).mean()*100
    print("cross_validation score=",crossval)
    print('\n')

# %% [markdown]
# # Hypertuning

# %%
from sklearn.model_selection import GridSearchCV
dtc=DecisionTreeClassifier()

parameters={"criterion":["gini","entropy"],"splitter":['random','best'],"min_samples_leaf":[2,4,6,8]}
abc=GridSearchCV(dtc,parameters)
abc.fit(x_train,y_train)
print(abc.best_params_)

# %%
dtc=DecisionTreeClassifier(criterion='entropy',min_samples_leaf=2,splitter='best')
dtc.fit(x_train,y_train)
y_pred=dtc.predict(x_test)
score=accuracy_score(y_test,y_pred)*100
print("accuracy",score)
crossval=cross_val_score(dtc,x1,y1,cv=5).mean()*100
print("cross_validation score=",crossval)
print("\n")
print("confusion matrix \n",confusion_matrix(y_test,y_pred))
print("\n")
print("classification report\n",classification_report(y_test,y_pred))

# %% [markdown]
# # saving the best model

# %%
import pickle
filename="Captone_Project_Final_classifier.pkl"
pickle.dump(dtc,open(filename,'wb'))

# %%
actual=np.array(y_test)

# %%
predicted=np.array(y_pred)

# %% [markdown]
# # comparing the actual and predicted values

# %%
df_com=pd.DataFrame({"actual values":actual,"predicted values":predicted})
df_com
